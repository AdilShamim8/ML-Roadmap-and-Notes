# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       line-height: 1.6;
#       background-color: #f9f9f9;
#       margin: 20px;
#       color: #333;
#     }
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#       background: #fff;
#       padding: 25px 40px;
#       box-shadow: 0 2px 5px rgba(0,0,0,0.1);
#     }
#     h1, h2, h3 {
#       color: #2c3e50;
#       margin-top: 30px;
#     }
#     p {
#       margin: 10px 0;
#     }
#     .formula {
#       background: #eef;
#       border: 1px solid #ccd;
#       padding: 10px;
#       margin: 15px 0;
#       overflow-x: auto;
#     }
#     pre {
#       background: #f4f4f4;
#       border: 1px solid #ddd;
#       padding: 15px;
#       overflow-x: auto;
#     }
#     code {
#       font-family: Consolas, monospace;
#     }
#     .section {
#       margin-bottom: 40px;
#     }
#   </style>
# </head>
# <body>
#   <div class="container">
#     <h1> Decision Tree Notes</h1>
#     <p>
#       These notes provide an in-depth overview of decision trees—a popular supervised learning algorithm used for classification and regression. The document covers key concepts, essential formulas (displayed using MathML), and includes a Python example that demonstrates building a decision tree with scikit-learn.
#     </p>
#     <!-- Section 1: Introduction -->
#     <div class="section">
#       <h2>1. Introduction</h2>
#       <p>
#         A <strong>decision tree</strong> is a tree-like model used for decision making. It splits data into subsets based on different conditions (if–then–else rules), leading to a tree structure with:
#       </p>
#       <ul>
#         <li><strong>Root Node</strong>: The starting point representing the entire dataset.</li>
#         <li><strong>Internal (Decision) Nodes</strong>: Nodes where data is split based on a condition.</li>
#         <li><strong>Branches</strong>: The outcomes of each decision.</li>
#         <li><strong>Leaf (Terminal) Nodes</strong>: Final nodes that hold the predicted outcome or class label.</li>
#       </ul>
#     </div>
#     <!-- Section 2: Key Concepts and Formulas -->
#     <div class="section">
#       <h2>2. Key Concepts and Formulas</h2>
#       <h3>2.1 Entropy</h3>
#       <p>
#         Entropy measures the impurity or uncertainty in a dataset. For a dataset <em>S</em> with <em>n</em> classes having probabilities \(p_1, p_2, \dots, p_n\), entropy is defined as:
#       </p>
#       <div class="formula">
#         <math xmlns="http://www.w3.org/1998/Math/MathML">
#           <mrow>
#             <mi>E</mi><mo stretchy="false">(</mo><mi>S</mi><mo stretchy="false">)</mo>
#             <mo>=</mo>
#             <mo>&#x2212;</mo>
#             <munder>
#               <mo>&#x2211;</mo>
#               <mrow>
#                 <mi>i</mi>=1
#               </mrow>
#             </munder>
#             <mi>p</mi><mi>i</mi>
#             <mo>&#x22C5;</mo>
#             <mi>log</mi>
#             <msub>
#               <mi>2</mi>
#               <mrow></mrow>
#             </msub>
#             <mi>p</mi><mi>i</mi>
#           </mrow>
#         </math>
#       </div>
#       <p>
#         <em>Example:</em> If a node has 9 positive and 5 negative samples, then:
#       </p>
#       <div class="formula">
#         <math xmlns="http://www.w3.org/1998/Math/MathML">
#           <mrow>
#             <mi>E</mi><mo stretchy="false">(</mo><mi>S</mi><mo stretchy="false">)</mo>
#             <mo>=</mo>
#             <mo>&#x2212;</mo>
#             <mrow>
#               <mfrac>
#                 <mn>9</mn>
#                 <mn>14</mn>
#               </mfrac>
#               <mo>&#x22C5;</mo>
#               <mi>log</mi>
#               <msub>
#                 <mi>2</mi>
#                 <mrow></mrow>
#               </msub>
#               <mfrac>
#                 <mn>9</mn>
#                 <mn>14</mn>
#               </mfrac>
#             </mrow>
#             <mo>+</mo>
#             <mrow>
#               <mfrac>
#                 <mn>5</mn>
#                 <mn>14</mn>
#               </mfrac>
#               <mo>&#x22C5;</mo>
#               <mi>log</mi>
#               <msub>
#                 <mi>2</mi>
#                 <mrow></mrow>
#               </msub>
#               <mfrac>
#                 <mn>5</mn>
#                 <mn>14</mn>
#               </mfrac>
#             </mrow>
#           </mrow>
#         </math>
#       </div>
#       <h3>2.2 Information Gain</h3>
#       <p>
#         Information Gain measures the reduction in entropy after splitting a dataset \(S\) on an attribute \(A\). It is calculated as:
#       </p>
#       <div class="formula">
#         <math xmlns="http://www.w3.org/1998/Math/MathML">
#           <mrow>
#             <mi>IG</mi><mo stretchy="false">(</mo><mi>S</mi><mo>,</mo><mi>A</mi><mo stretchy="false">)</mo>
#             <mo>=</mo>
#             <mi>E</mi><mo stretchy="false">(</mo><mi>S</mi><mo stretchy="false">)</mo>
#             <mo>&#x2212;</mo>
#             <munderover>
#               <mo>&#x2211;</mo>
#               <mrow>
#                 <mi>v</mi>&isin;<mi>Values</mi>(<mi>A</mi>)
#               </mrow>
#               <mrow></mrow>
#             </munderover>
#             <mfrac>
#               <mi>|S_v|</mi>
#               <mi>|S|</mi>
#             </mfrac>
#             <mo>&#x22C5;</mo>
#             <mi>E</mi><mo stretchy="false">(</mo><mi>S_v</mi><mo stretchy="false">)</mo>
#           </mrow>
#         </math>
#       </div>
#     <h3>2.3 Gini Impurity</h3>
#       <p>
#         Gini Impurity is another measure used (especially in CART) to evaluate splits. It is defined as:
#       </p>
#       <div class="formula">
#         <math xmlns="http://www.w3.org/1998/Math/MathML">
#           <mrow>
#             <mi>G</mi><mo stretchy="false">(</mo><mi>S</mi><mo stretchy="false">)</mo>
#             <mo>=</mo>
#             <mn>1</mn>
#             <mo>&#x2212;</mo>
#             <munderover>
#               <mo>&#x2211;</mo>
#               <mrow>
#                 <mi>i</mi>=1
#               </mrow>
#               <mi>n</mi>
#             </munderover>
#             <msup>
#               <mi>p</mi><mi>i</mi>
#               <mn>2</mn>
#             </msup>
#           </mrow>
#         </math>
#       </div>
#     </div>
#     <!-- Section 3: Python Code Example -->
#     <div class="section">
#       <h2>3. Python Code Example</h2>
#       <p>
#         The following Python code uses scikit-learn to build a decision tree classifier on the Iris dataset.
#       </p>
#       <pre><code class="language-python">
# # Import necessary libraries
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import load_iris
# from sklearn.tree import DecisionTreeClassifier, plot_tree
# from sklearn.model_selection import train_test_split
#
# # Load the Iris dataset
# data = load_iris()
# X = data.data        # Features
# y = data.target      # Target labels
#
# # Split the dataset into training and testing sets (75% train, 25% test)
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.25, random_state=42
# )
#
# # Create and train the Decision Tree Classifier using 'entropy'
# clf = DecisionTreeClassifier(criterion='entropy', random_state=42)
# clf.fit(X_train, y_train)
#
# # Evaluate the model
# accuracy = clf.score(X_test, y_test)
# print("Test Accuracy: {:.2f}%".format(accuracy * 100))
#
# # Visualize the Decision Tree
# plt.figure(figsize=(15, 10))
# plot_tree(
#     clf,
#     feature_names=data.feature_names,
#     class_names=data.target_names,
#     filled=True,
#     rounded=True
# )
# plt.title("Decision Tree on Iris Dataset")
# plt.show()
#       </code></pre>
#     </div>
#     <!-- Section 4: Conclusion -->
#     <div class="section">
#       <h2>4. Conclusion</h2>
#       <p>
#         Decision trees provide an intuitive way to model decisions based on data. These notes reviewed key concepts including entropy, information gain, and Gini impurity using MathML formulas.
#       </p>
#       <p>
#         The Python example demonstrates how to build and visualize a decision tree using scikit-learn. By understanding these concepts and implementing them in code, you can apply decision trees to various classification and regression problems.
#       </p>
#     </div>
#   </div>
# </body>
# </html>

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split

# Load the Iris dataset
data = load_iris()
X = data.data        # Feature matrix
y = data.target      # Target vector

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Initialize and train the Decision Tree Classifier
clf = DecisionTreeClassifier(criterion='entropy', random_state=42)
clf.fit(X_train, y_train)

# Evaluate the model
accuracy = clf.score(X_test, y_test)
print("Test Accuracy: {:.2f}%".format(accuracy * 100))

# Visualize the decision tree
plt.figure(figsize=(15, 10))
plot_tree(
    clf,
    feature_names=data.feature_names,
    class_names=data.target_names,
    filled=True,
    rounded=True
)
plt.title("Decision Tree on Iris Dataset")
plt.show()
# Out:
# Test Accuracy: 97.37%
